# %%
import cv2 as cv
import numpy as np
from matplotlib import cm
from matplotlib import pyplot as plt

img  = cv.imread('images/profile.jpg')

sobel_x  = cv.Sobel(img,-1,1,0,ksize=5)
sobel_y  = cv.Sobel(img,-1,1,0,ksize=5)

plt.imshow(sobel_y, cmap=cm.gray)
plt.show()
