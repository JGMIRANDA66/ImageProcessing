# %%
from PIL import Image
from pylab import *

im = array(Image.open('images/profile.jpg'))
imshow(im)
x = [100, 150, 300, 400]
y = [50, 500, 200, 500]
plot(x,y, 'r*')
show()

im2 = array(Image.open('images/profile.jpg'))
imshow(im2)
x = [100, 150, 300, 400]
y = [50, 500, 200, 500]
plot(x[:2],y[:2], 'r')
plot(x[2:],y[2:], 'ks:')
title('Plotting "Profile.jpg"')
show()

im3 = array(Image.open('images/profile.jpg'))
imshow(im3)
#select 4 points
pt = ginput(4)
print('You selected : ', pt)
show()
# Out:
# /tmp/ipykernel_287/2068749640.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   pt = ginput(4)
# You selected :  []
