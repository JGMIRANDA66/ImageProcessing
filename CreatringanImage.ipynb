# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm


x = np.random.randint(0,255,(300,400)).astype('uint8')
plt.imshow(x,cmap = cm.gray)
plt.imshow(x)
plt.show()

y  = np.random.randint(0,255,(300,400,3)).astype('uint8')
plt.imshow(y)
plt.show()
