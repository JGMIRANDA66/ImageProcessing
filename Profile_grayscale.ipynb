# %%
from PIL import Image
img  = Image.open('images/profile.jpg')
img.show()
new_img = img.convert('L')
new_img.show();
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=749x707>
# <PIL.Image.Image image mode=L size=749x707>
