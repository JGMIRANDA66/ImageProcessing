# %%
import numpy as np
import matplotlib.pyplot as plt

A = plt.imread('images/lena_color.jpg')
print(A)
print(np.shape(A))
print(type(A))
print(A.dtype)
plt.imshow(A)
plt.show()
# Out:
# [[[195 113  75]
#   [195 113  75]
#   [196 114  76]
#   ...
#   [143  81  60]
#   [144  79  57]
#   [143  78  56]]
#
#  [[196 114  76]
#   [196 114  76]
#   [196 114  76]
#   ...
#   [144  79  57]
#   [146  81  59]
#   [149  84  62]]
#
#  [[197 115  77]
#   [197 115  77]
#   [197 115  77]
#   ...
#   [146  80  56]
#   [148  82  58]
#   [150  84  60]]
#
#  ...
#
#  [[167  86  59]
#   [168  87  60]
#   [173  92  63]
#   ...
#   [ 63  37  38]
#   [ 63  37  38]
#   [ 66  40  41]]
#
#  [[166  85  58]
#   [166  85  58]
#   [172  91  62]
#   ...
#   [ 63  39  39]
#   [ 64  40  40]
#   [ 67  43  43]]
#
#  [[164  83  56]
#   [164  83  56]
#   [172  91  62]
#   ...
#   [ 65  41  41]
#   [ 66  42  42]
#   [ 69  45  45]]]
# (512, 512, 3)
# <class 'numpy.ndarray'>
# uint8
